# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import numpy as np

# %% [markdown]
# # Đọc và xem trước 5 dòng dữ liệu

# %%
tracks_read = pd.read_csv('track.csv')

# %%
tracks_read.head(5)
# Out:
#    track_id                                         track_name  \
# 0     24169  Friday Feel Good Quick Mix ~ We R Famlily 70's...
# 1     10804  DJ Pajik[CDJ™] FT DJ BCD [CDJ™ ] ~ DJ KESAYANG...
# 2     12911                            Rooh Ya Hawa روح يا هوى
# 3     25944  Nejla Belhaj Ft Azaiez Yacine - Asfour "عصفور ...
# 4     12981                                 شهاب حسنى بحبك وبس
#
#                                                  url  \
# 0  https://www.soundcloud.com/mix966fm/friday-fee...
# 1  https://www.soundcloud.com/fajri-gunawan-88560...
# 2  https://www.soundcloud.com/rock-real/rooh-ya-hawa
# 3  https://www.soundcloud.com/y-a-1/nejla-belhaj-...
# 4  https://www.soundcloud.com/jeelmusic8090/zamrh...
#
#                    datetime  track_tag  track_play  track_like  track_repost
# 0  2013-10-10T17:26:49.000Z      Disco        7610         136             6
# 1  2020-07-04T15:12:33.000Z     funkot        6118         171             5
# 2  2012-01-08T09:45:28.000Z        NaN       13237         186            36
# 3  2015-02-08T22:31:54.000Z      Cover       95621        2516           462
# 4  2015-07-26T18:58:01.000Z  walid aly      202192        3904            45

# %% [markdown]
# # Số lượng dòng và cột

# %%
tracks_read.shape
# Out:
# (1036, 8)

# %% [markdown]
# Như vậy, dữ liệu có 1036 dòng và 8 cột

# %% [markdown]
# # Ý nghĩa các cột

# %% [markdown]
# Nội dung và ý nghĩa từng cột
# - track_id: mã id từng track
# - track_name: tên của track
# - url: đường dẫn liên kết đến website
# - datetime: ngày xuất bản
# - track_tag: thể loại của track
# - track_plat: thời gian, độ dài
# - track_like: số lượng người thích
# - track_repost: số lượng người đăng lại

# %% [markdown]
# # Kiểu dữ liệu

# %%
tracks_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_id      1036 non-null   int64
#  1   track_name    1036 non-null   object
#  2   url           1036 non-null   object
#  3   datetime      1036 non-null   object
#  4   track_tag     644 non-null    object
#  5   track_play    1036 non-null   int64
#  6   track_like    1036 non-null   int64
#  7   track_repost  1036 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 64.9+ KB

# %% [markdown]
# # Hiển thị ra các thông số như giá trị trung bình, độ lệch chuẩn, min, max và tỷ lệ phần trăm của các cột

# %%
tracks_read.describe()
# Out:
#            track_id    track_play    track_like   track_repost
# count   1036.000000  1.036000e+03  1.036000e+03    1036.000000
# mean   13015.160232  1.531258e+06  3.621179e+04    1208.250000
# std     7610.863452  4.215300e+06  9.868376e+04    5377.040556
# min       38.000000  8.800000e+01  4.000000e+00       1.000000
# 25%     6640.250000  3.731150e+04  5.720000e+02      24.000000
# 50%    12791.000000  2.246330e+05  3.848000e+03     134.000000
# 75%    19394.750000  1.024204e+06  2.432225e+04     762.000000
# max    26408.000000  7.220902e+07  1.054419e+06  148942.000000

# %% [markdown]
# # Có trùng lắp không

# %%
num_duplicated_rows = tracks_read .index.duplicated().sum()
print(num_duplicated_rows)
# Out:
# 0

# %% [markdown]
# # Số lượng missing

# %%
tracks_read.isnull().sum()
# Out:
# track_id          0
# track_name        0
# url               0
# datetime          0
# track_tag       392
# track_play        0
# track_like        0
# track_repost      0
# dtype: int64

# %% [markdown]
# Như vậy chỉ có cột track_tag là bị miss dữ liệu

# %% [markdown]
# # Xử lý nan

# %%
tracks_read = tracks_read.fillna("Missing")

# %% [markdown]
# kiểm tra lại

# %%
tracks_read.isnull().sum()
# Out:
# track_id        0
# track_name      0
# url             0
# datetime        0
# track_tag       0
# track_play      0
# track_like      0
# track_repost    0
# dtype: int64

# %% [markdown]
# # Data Outliers

# %% [markdown]
# Ở đây team sẽ check ở 3 cột: track_play, track_like và track_repost

# %% [markdown]
# <li>Đầu tiên track_play.</li>

# %%
sns.displot(tracks_read['track_play'])

# %%
sns.boxplot(tracks_read['track_play'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='track_play'>

# %%
# find the limits
upper_limit = tracks_read['track_play'].mean() + 3*tracks_read['track_play'].std()
lower_limit = tracks_read['track_play'].mean() - 3*tracks_read['track_play'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 14177159.377218971
# lower limit: -11114643.230500823

# %%
# find the outliers
tracks_read.loc[(tracks_read['track_play'] > upper_limit) | (tracks_read['track_play'] < lower_limit)]
# Out:
#       track_id                                         track_name  \
# 95       21104                       Still Cold / Pathway Private
# 227      10125  AFROTO - FAR2 KHEBRA (عفروتو - فرق خبرة (الاغن...
# 346       5397  Sherine Abdel Wahab | شيرين عبد الوهاب - أغاني...
# 390       7629                           ادهم نابلسي | شدني غمرني
# 450       2824                           اديني رجعتلك - عمرو دياب
# 473       7481  اغنية اصالة - 60 دقيقة حياة 2015 | النسخه الاصليه
# 530       7577  رامي جمال - فترة مش سهلة   Ramy Gamal - Fatra ...
# 577       7453                  Wegz - KEDA KEDA   ويجز - كدا كدا
# 645       2562         حسام حبيب - شايف نفسى فيك - البوم فرق كتير
# 753        486  كارمن سليمان - لما تشوفك عيني  | Carmen Solima...
# 773      11282  حسين الجسمي - وحشتنى دنيتى (حصريا)(مصريه ) - 2016
# 790      14527  مهرجان - وداع يا دنيا وداع | حمو بيكا | حسن شا...
# 806       4149  Deep Sleep, Calming, Relaxing and Soothing Mus...
# 847      10280  Moustafa Hagag - Ya Mna3na3 | مصطفي حجاج - يا ...
# 931      23239                   ''كوكب الشرق ام كلثوم" امل حياتى
# 1026     24525    Martin Garrix - Animals (Original Mix) OUT NOW!
# 1035      5278                              أحمد كامل - زدنى حباَ
#
#                                                     url  \
# 95    https://www.soundcloud.com/night_lovell/still-...
# 227   https://www.soundcloud.com/rammygamal/afroto-f...
# 346   https://www.soundcloud.com/free-music-egypt/sh...
# 390   https://www.soundcloud.com/zeka-music-ar/11eze...
# 450   https://www.soundcloud.com/megaalalmy/amr-diab...
# 473         https://www.soundcloud.com/hawssa2/60-2015a
# 530   https://www.soundcloud.com/mohamed-kabeel/ramy...
# 577   https://www.soundcloud.com/no-r-992488867/wegz...
# 645   https://www.soundcloud.com/user-130191386/u7vk...
# 753   https://www.soundcloud.com/carmensolimanoffici...
# 773    https://www.soundcloud.com/assalya-mohamed/2016a
# 790   https://www.soundcloud.com/shakosh2020/2qweq01...
# 806   https://www.soundcloud.com/sam_relaxation/30-m...
# 847   https://www.soundcloud.com/njmusicproductions/...
# 931   https://www.soundcloud.com/gharam-mostafa/pbyl...
# 1026  https://www.soundcloud.com/martingarrix/martin...
# 1035     https://www.soundcloud.com/soo-mt/tffax2azuxgx
#
#                       datetime         track_tag  track_play  track_like  \
# 95    2015-03-09T00:20:37.000Z              scpp    14710699      204465
# 227   2021-11-04T12:33:27.000Z             World    17871305      482034
# 346   2016-11-19T11:21:18.000Z             World    18584712      668090
# 390   2017-10-10T12:58:45.000Z           Missing    17136942      435563
# 450   2015-03-17T18:00:47.000Z               Amr    20970558      478193
# 473   2015-03-21T12:19:24.000Z             اصالة    24198790      669528
# 530   2013-10-08T16:54:25.000Z               New    16027505      460091
# 577   2019-07-13T10:28:33.000Z           Missing    26905387      664757
# 645   2016-10-21T03:47:09.000Z           Missing    16960283      504541
# 753   2016-07-03T23:14:57.000Z         Classical    35475283      951706
# 773   2016-03-29T15:29:11.000Z             World    26194951      750408
# 790   2019-11-16T16:58:23.000Z           Missing    36185831     1054419
# 806   2015-12-13T04:26:31.000Z             Relax    26315104      301781
# 847   2015-01-01T05:00:16.000Z             World    33520538      899178
# 931   2014-10-15T19:23:31.000Z             2adiM    17951332      643124
# 1026  2013-06-23T10:45:52.000Z           Subkick    72209021     1027798
# 1035  2016-02-19T23:08:17.000Z  The #best #Raper    20343467      531544
#
#       track_repost
# 95           13409
# 227           3094
# 346          12440
# 390           7143
# 450           8811
# 473          11243
# 530          10264
# 577           4423
# 645          14143
# 753          31990
# 773          17520
# 790          11991
# 806          11017
# 847          20102
# 931          12814
# 1026        148942
# 1035          6660

# %%
# trimming - delete the outlier data
new_df = tracks_read.loc[(tracks_read['track_play'] <= upper_limit) & (tracks_read['track_play'] >= lower_limit)]
print('before removing outliers:', len(tracks_read))
print('after removing outliers:',len(new_df))
print('outliers:', len(tracks_read)-len(new_df))
# Out:
# before removing outliers: 1036
# after removing outliers: 1019
# outliers: 17

# %% [markdown]
# <li>Tiếp đến track_like.</li>

# %%
sns.displot(new_df['track_like'])

# %%
sns.boxplot(new_df['track_like'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='track_like'>

# %%
# find the limits
upper_limit = new_df['track_like'].mean() + 3*new_df['track_like'].std()
lower_limit = new_df['track_like'].mean() - 3*new_df['track_like'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 189296.4365800495
# lower limit: -136719.01165365108

# %%
# find the outliers
new_df.loc[(new_df['track_like'] > upper_limit) | (new_df['track_like'] < lower_limit)]
# Out:
#      track_id                                         track_name  \
# 10       8211          دلع البنوتة - مسلسل دلع بنات - غناء عزيزة
# 11      14439  مواويل رضا البحراوي وعبسلام بداري الأه & انا ا...
# 12       7641  Mohamed El Sharnouby - Heta Men El Khayal | مح...
# 30      16234  Majid Almohandis Bahebak( ماجد المهندس  بحبك  ...
# 132      5337                               تامر عاشور باينة ضاع
# 162     16477                    على مين الملامه ..شرين .. كامله
# 215      1546                               نانسى عجرم - يا بنات
# 262     13593        Steve Aoki & Louis Tomlinson - Just Hold On
# 288      4544                           اياد جيان | دنيته وحشانى
# 290      2310                        الركن البعيد الهادى - أنغام
# 316     11620                      بتعاتبنى على كلمة - جورج وسوف
# 320     13870  Mohamed Mounir - El Leila Ya Samra / محمد منير...
# 375      5473                                 مُسلِم - هنِيآلِك.
# 386     10312  مهرجان صحبي انا ممكن اقولك كلمه ( انا عايزك ان...
# 437      5354                            نفسى اقولك - تامر عاشور
# 456     13255                            عمرو دياب انا بحبك اكتر
# 593      2323                                 أنغام - مجبش سيرتى
# 698     21341  Sebi Rohek - Mohamed Adawya | سيبي روحك - محمد...
# 768      8184  نانسى عجرم .. زمان كان عندى قلب .. Nancy Ajram...
# 770     13757              اوعدني جنبي تعيش - عبد الفتاح الجريني
# 793     19895  Tazkarti - Hamza Namira | التــغريبـه 2 ( تذكر...
# 798      8524  Happy Birthday 7- اغنية النهاردة عيد ميلاد حما...
# 804      8170                    سالت كل المجروحين at اغانى شعبى
# 943     20797                      على رمش عيونها من فيلم القشاش
# 967     13475                                  عامل ايه في حياتك
# 968     10341                   اغنية تامر حسني - مربوطين في بعض
# 977     25807  Najat Al Saghira (Ana B3sh2 El-Ba7r) أنا بعشق ...
# 982      5337                               تامر عاشور باينة ضاع
#
#                                                    url  \
# 10     https://www.soundcloud.com/7adota7/qvlxvhbi9lxh
# 11         https://www.soundcloud.com/slah-trika/2016a
# 12   https://www.soundcloud.com/earthproductionst/m...
# 30   https://www.soundcloud.com/mohamed-ashraf-sala...
# 132      https://www.soundcloud.com/pk-29/jxw2u4shil81
# 162  https://www.soundcloud.com/ariqamzyvrs/zfkuga3...
# 215   https://www.soundcloud.com/music-fc/pysezdwfmw80
# 262  https://www.soundcloud.com/steveaoki/steve-aok...
# 288  https://www.soundcloud.com/zeka-music-3/eyad-j...
# 290  https://www.soundcloud.com/walid-gerges/s9pn9y...
# 316    https://www.soundcloud.com/lotfe-1/ue50c33ttaii
# 320  https://www.soundcloud.com/amresmail/mohamed-m...
# 375  https://www.soundcloud.com/r-s-s590183/v5q7qhg...
# 386     https://www.soundcloud.com/srelarhaby/2021a-10
# 437  https://www.soundcloud.com/moha-mahmoud-1/ykdo...
# 456  https://www.soundcloud.com/ali-mahmoud-24/w9zm...
# 593  https://www.soundcloud.com/noor-mohamed-18/0li...
# 698  https://www.soundcloud.com/mohamedadawyaoffici...
# 768  https://www.soundcloud.com/dina-mohamed-15/nan...
# 770  https://www.soundcloud.com/a7md7star/xxp5pzepkheq
# 793  https://www.soundcloud.com/ultras-hamza-namira...
# 798  https://www.soundcloud.com/mina-zaki-5/happy-b...
# 804         https://www.soundcloud.com/amr-salem-63/at
# 943  https://www.soundcloud.com/mohamed-mady-01/ist...
# 967  https://www.soundcloud.com/hebasabry/oatelhqkkgmk
# 968  https://www.soundcloud.com/wasta-hits/lagcrvkm...
# 977  https://www.soundcloud.com/arab_music/najat-an...
# 982      https://www.soundcloud.com/pk-29/jxw2u4shil81
#
#                      datetime                                 track_tag  \
# 10   2014-06-25T23:47:11.000Z                                  دلع_بنات
# 11   2015-11-23T15:36:38.000Z                                    مواويل
# 12   2019-03-29T01:21:49.000Z                                       Pop
# 30   2019-02-03T12:27:56.000Z                                   Missing
# 132  2013-09-16T04:24:48.000Z                                    Arabic
# 162  2015-07-10T00:00:37.000Z                                      شرين
# 215  2012-09-25T15:41:03.000Z  http://www.facebook.com/pages/%D8%A7%D8%
# 262  2016-12-10T19:57:30.000Z                               Dance & EDM
# 288  2016-07-27T00:38:48.000Z                                   Missing
# 290  2012-08-19T00:07:42.000Z                                   Missing
# 316  2014-05-13T22:02:49.000Z                                   ِarabic
# 320  2013-06-15T19:42:33.000Z                                   Missing
# 375  2020-06-18T20:56:47.000Z                                   Missing
# 386  2021-08-23T17:01:05.000Z                                     World
# 437  2013-10-06T12:06:56.000Z                                     Tamer
# 456  2015-02-25T01:20:36.000Z                                 عمرو دياب
# 593  2013-09-09T01:00:25.000Z                                     انغام
# 698  2016-09-27T04:00:15.000Z                          Alternative Rock
# 768  2013-05-24T04:46:30.000Z                                   Missing
# 770  2017-04-27T16:16:26.000Z                                     World
# 793  2012-01-17T22:59:50.000Z                                   Missing
# 798  2013-10-16T12:30:10.000Z                                     حمادة
# 804  2014-08-09T21:22:06.000Z                                   Missing
# 943  2013-11-08T01:18:15.000Z                                    القشاش
# 967  2019-12-03T10:28:58.000Z                                   Missing
# 968  2018-08-02T04:43:00.000Z                                   Missing
# 977  2012-02-01T07:23:43.000Z                                   Missing
# 982  2013-09-16T04:24:48.000Z                                    Arabic
#
#      track_play  track_like  track_repost
# 10      9252005      214546          9381
# 11     14126978      402678          6104
# 12     12755767      307105          2917
# 30      9366863      207680          2214
# 132     7458862      219286          3877
# 162     6893205      217497          6175
# 215    13287614      356885         16606
# 262    13487778      195476         11593
# 288     7844900      213672          6499
# 290     7719128      214475         10213
# 316    11820954      349039          5599
# 320     9318891      252498          4571
# 375     9361053      213700          1520
# 386     7797832      198834           913
# 437    13213739      376858          5833
# 456     7153107      204112          3424
# 593     6870043      222888          5716
# 698     6336144      190316          2541
# 768    11915528      341647         14523
# 770     6395918      201621          2522
# 793     9294584      217321          8894
# 798    10168602      267212          9045
# 804     9512367      258348          6557
# 943    10797942      326574          8896
# 967    11663086      254018          2416
# 968    14101123      389924          4993
# 977     9024548      250138         12433
# 982     7458889      219287          3877

# %%
new_dff = new_df.loc[(new_df['track_like'] <= upper_limit) & (new_df['track_like'] >= lower_limit)]
print('before removing outliers:', len(new_df))
print('after removing outliers:',len(new_dff))
print('outliers:', len(new_df)-len(new_dff))
# Out:
# before removing outliers: 1019
# after removing outliers: 991
# outliers: 28

# %%
new_dff.head(5)
# Out:
#    track_id                                         track_name  \
# 0     24169  Friday Feel Good Quick Mix ~ We R Famlily 70's...
# 1     10804  DJ Pajik[CDJ™] FT DJ BCD [CDJ™ ] ~ DJ KESAYANG...
# 2     12911                            Rooh Ya Hawa روح يا هوى
# 3     25944  Nejla Belhaj Ft Azaiez Yacine - Asfour "عصفور ...
# 4     12981                                 شهاب حسنى بحبك وبس
#
#                                                  url  \
# 0  https://www.soundcloud.com/mix966fm/friday-fee...
# 1  https://www.soundcloud.com/fajri-gunawan-88560...
# 2  https://www.soundcloud.com/rock-real/rooh-ya-hawa
# 3  https://www.soundcloud.com/y-a-1/nejla-belhaj-...
# 4  https://www.soundcloud.com/jeelmusic8090/zamrh...
#
#                    datetime  track_tag  track_play  track_like  track_repost
# 0  2013-10-10T17:26:49.000Z      Disco        7610         136             6
# 1  2020-07-04T15:12:33.000Z     funkot        6118         171             5
# 2  2012-01-08T09:45:28.000Z    Missing       13237         186            36
# 3  2015-02-08T22:31:54.000Z      Cover       95621        2516           462
# 4  2015-07-26T18:58:01.000Z  walid aly      202192        3904            45

# %% [markdown]
# <li>Kế tiếp là track_repost.</li>

# %%
sns.displot(new_dff['track_repost'])

# %%
sns.boxplot(new_dff['track_repost'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='track_repost'>

# %%
# find the limits
upper_limit = new_dff['track_repost'].mean() + 3*new_dff['track_repost'].std()
lower_limit = new_dff['track_repost'].mean() - 3*new_dff['track_repost'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 6762.533117838671
# lower limit: -5297.570453862889

# %%
df = new_dff.loc[(new_dff['track_repost'] <= upper_limit) & (new_dff['track_repost'] >= lower_limit)]
print('before removing outliers:', len(new_dff))
print('after removing outliers:',len(df))
print('outliers:', len(new_dff)-len(df))
# Out:
# before removing outliers: 991
# after removing outliers: 974
# outliers: 17

# %%
df.shape
# Out:
# (974, 8)

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Top 10 thể loại phổ biến nhất

# %%
top_genre= df.sort_values('track_tag', ascending=False)
top_genre = top_genre['track_tag'].value_counts().rename_axis('track_tag').reset_index(name='counts')
top_genre = top_genre.drop(top_genre[top_genre['track_tag']=='Missing'].index)
top_genre.head(10)
# Out:
#       track_tag  counts
# 1         World      24
# 2        Reggae      15
# 3     VlogMusic      15
# 4        Comedy      14
# 5        Arabic      13
# 6           Pop      11
# 7         House      11
# 8    Soundtrack      11
# 9    Deep House       9
# 10  Dance & EDM       9

# %%
plt.figure(figsize=(15,5))
plt.bar(top_genre.head(10)['track_tag'],top_genre.head(10)['counts'])
plt.show()

# %% [markdown]
# ## Có phải số lượng tracks phổ biến gần đây đều là những tracks mới được phát hành không?

# %%
dates_tracks = df['datetime'].squeeze()
dates_tracks = pd.to_datetime(dates_tracks, format='%Y-%m-%d %H:%M:%S')
years = dates_tracks.dt.year

years_tracks = years.value_counts().rename_axis('datetime').reset_index(name='frequency')

# %%
sns.displot(years, discrete=True, aspect=3)
plt.show()

# %%
sns.displot(years, discrete=True, aspect=3, kde=True)

# %% [markdown]
# <b>Nhìn vào biểu đồ: </b>
# <ul>
# <li>Câu trả lời là không. Ta dễ dàng nhìn thấy từ 2020 có xu hướng giảm dần tới 2022 và có xướng tiếp tục giảm.</li>
# <li>Phần lớn tracks được phát hành tập trung trong năm 2013, 2014 và 2015. Trong đó 2015 là cao nhất.</li>
# <li>Năm 2010 là năm ít upload nhất.</li>
# </ul>

# %%
sns.boxplot(y='frequency', data=years_tracks)
# Out:
# <AxesSubplot:ylabel='frequency'>

# %% [markdown]
# <b>Nhận xét: </b>
# <ul>
# <li>Một nửa số năm có lượng tracks phát hành trên 78.</li>
# <li>75% các năm có lượng tracks phát hành từ 40 trở lên .</li>
# </ul>

# %% [markdown]
# ## Các tracks đăng lại (repost) có ảnh hưởng đến lượt nghethích (like) và thời gian không (play) không

# %%
h = df[['track_play', 'track_like', 'track_repost']]

corr = h.corr()
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(h.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(h.columns)
ax.set_yticklabels(h.columns)
plt.show()

# %% [markdown]
# <b>Nhìn vào biểu đồ: </b>
# <li>Ta thấy được bài hát (track) đăng lại đều tác động đến thời gian (track_play) và lượt thích (track_like).</li>
# <li>Đồng thời ta cũng thấy một số tương quan khác.</li>

# %% [markdown]
# ## Các lượt thích (track_like), đăng lại (track_repost) và thời gian (track_play) có những mối liên quan đến nhau hay không.

# %%
sns.scatterplot(data=h, x="track_like", y="track_play")
plt.show()
sns.scatterplot(data=h, x="track_like", y="track_repost")
plt.show()
sns.scatterplot(data=h, x="track_play", y="track_repost")
plt.show()

# %%
plt.figure(figsize=(40,100))
temp = df
sns.barplot(y="track_tag", x='track_like', data=temp[['track_tag', 'track_like']])
# Out:
# <AxesSubplot:xlabel='track_like', ylabel='track_tag'>
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32184 (\N{CJK UNIFIED IDEOGRAPH-7DB8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23067 (\N{CJK UNIFIED IDEOGRAPH-5A1B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 27138 (\N{CJK UNIFIED IDEOGRAPH-6A02}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24930 (\N{CJK UNIFIED IDEOGRAPH-6162}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25671 (\N{CJK UNIFIED IDEOGRAPH-6447}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23560 (\N{CJK UNIFIED IDEOGRAPH-5C08}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23660 (\N{CJK UNIFIED IDEOGRAPH-5C6C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 29256 (\N{CJK UNIFIED IDEOGRAPH-7248}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 29590 (\N{CJK UNIFIED IDEOGRAPH-7396}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22777 (\N{CJK UNIFIED IDEOGRAPH-58F9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 34311 (\N{CJK UNIFIED IDEOGRAPH-8607}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20553 (\N{CJK UNIFIED IDEOGRAPH-5049}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.head(3)
# Out:
#    track_id                                         track_name  \
# 0     24169  Friday Feel Good Quick Mix ~ We R Famlily 70's...
# 1     10804  DJ Pajik[CDJ™] FT DJ BCD [CDJ™ ] ~ DJ KESAYANG...
# 2     12911                            Rooh Ya Hawa روح يا هوى
#
#                                                  url  \
# 0  https://www.soundcloud.com/mix966fm/friday-fee...
# 1  https://www.soundcloud.com/fajri-gunawan-88560...
# 2  https://www.soundcloud.com/rock-real/rooh-ya-hawa
#
#                    datetime track_tag  track_play  track_like  track_repost
# 0  2013-10-10T17:26:49.000Z     Disco        7610         136             6
# 1  2020-07-04T15:12:33.000Z    funkot        6118         171             5
# 2  2012-01-08T09:45:28.000Z   Missing       13237         186            36
